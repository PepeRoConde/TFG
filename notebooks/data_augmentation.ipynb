# %%
from dotenv import load_dotenv
load_dotenv('../.env')

from src.data.Offline_Dataset import Offline_Dataset
from src.plots.epoch_grids import epoch_grids

# %%
train_dataset = Offline_Dataset('../data/DRIVE/train_patches/',
                                data_augmentation=True,
                                total_epochs=100)
# Out:
# Loaded Offline Dataset:
#   Patches directory: ../data/DRIVE/train_patches/
#   Total patches: 165540
#   Patch size: 32x32
#   Overlap rate: 80.00%
#   Stride: 6
#   Label mode: vainilla
#   Output size: 2

# %%
epoch_grids(train_dataset, epochs=[0, 20, 50], grid_size=5)
