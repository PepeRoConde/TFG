# %%
from dotenv import load_dotenv
load_dotenv('.env')

from src.data.Online_Dataset import Online_Dataset
from src.plots.epoch_grids import epoch_grids

# %%
train_dataset = Online_Dataset('data/DRIVE/train/',
                               tamano_patch = 100,
                                aumento_datos=True,
                               modo_aumento_datos='fixo', # ou lineal
                                total_epochs=1000)

# %%
epoch_grids(train_dataset, epochs=[0], grid_size=10)
#epoch_grids(train_dataset, epochs=[0, 50, 100, 500, 1000], grid_size=8)
